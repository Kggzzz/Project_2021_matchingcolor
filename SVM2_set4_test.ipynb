# %% [markdown]
# <a href="https://colab.research.google.com/github/Kggzzz/Project_2021_matchingcolor/blob/main/SVM2_set4_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path = '/content/drive/My Drive/shadeimg/SVM shade'

# %%
os.listdir(path)
# Out:
# ['DD.xlsx',
#  'CC.xlsx',
#  'BB.xlsx',
#  'Shade_AA.xlsx',
#  'Shade_CC.xlsx',
#  'Shade_DD.xlsx',
#  'Shade_BB.xlsx',
#  'AA.xlsx',
#  'AA_2.xlsx',
#  'Shad_A.xlsx',
#  'Shad_B.xlsx',
#  'Shad_C.xlsx',
#  'Shad_D.xlsx',
#  'Setting4.xlsx',
#  'Color-checkerAA.xlsx',
#  'Color-checkerBB.xlsx',
#  'Color-checkerCC.xlsx',
#  'Setting2.xlsx',
#  'D3set51.csv',
#  'Setting1.xlsx',
#  'CheckerDD.xlsx',
#  'Setting3.xlsx',
#  'Setting6.xlsx',
#  'Setting5.xlsx',
#  'checkerShad_A .xlsx',
#  'checkerShad_B.xlsx',
#  'checkerShad_C.xlsx',
#  'D3Set5-61.xlsx',
#  'checkerShad_D.xlsx',
#  'Color-checkerDD.xlsx',
#  'Datapoint_1.xlsx',
#  'Datapoint_2.xlsx',
#  'Datapoint_3.xlsx',
#  'Datapoint_4.xlsx',
#  'Datapoint_6.xlsx',
#  'Datapoint_5.xlsx']

# %%
Set1 = os.path.join(path,'Datapoint_1.xlsx')
print(Set1)
# Out:
# /content/drive/My Drive/shadeimg/SVM shade/Datapoint_1.xlsx

# %%
Set2 = os.path.join(path,'Datapoint_2.xlsx')
print(Set2)
# Out:
# /content/drive/My Drive/shadeimg/SVM shade/Datapoint_2.xlsx

# %%
Set3 = os.path.join(path,'Datapoint_3.xlsx')
print(Set3)
# Out:
# /content/drive/My Drive/shadeimg/SVM shade/Datapoint_3.xlsx

# %%
Set4 = os.path.join(path,'Datapoint_4.xlsx')
print(Set4)
# Out:
# /content/drive/My Drive/shadeimg/SVM shade/Datapoint_4.xlsx

# %%
import numpy as np

# %%
from sklearn import metrics

# %%
from sklearn import datasets

# %%
from sklearn import svm

# %% [markdown]
# #AA

# %% [markdown]
# ##A1

# %%
table_A1Set1 = pd.read_excel(Set1 , sheet_name='A1_1')
table_A1Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  239.489003  226.557990  192.833617  244.087331  232.348673  200.770960
# 1  238.912751  225.914942  192.314585  243.395098  231.692882  199.660742
# 2  239.195520  226.261586  192.730947  243.708384  231.981414  200.541190
# 3  239.019317  226.444282  192.215486  243.864865  232.282039  200.238130
# 4  238.941644  225.877932  192.596461  243.859346  231.930119  200.289100
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  21.588832  49.723156  239.489003  21.910965  45.318399  244.087331    Set1
# 1  21.527392  49.805048  238.912751  22.027757  45.914698  243.395098    Set1
# 2  21.533642  49.591754  239.195520  21.870140  45.244055  243.708384    Set1
# 3  21.930687  49.944485  239.019317  22.111842  45.708790  243.864865    Set1
# 4  21.467576  49.520169  238.941644  21.852204  45.623651  243.859427    Set1
#
#   Ref Shad                                       Img
# 0  A1   A1  1665B5AE-934F-4116-AE19-3369544A125F.png
# 1  A1   A1  47C127AF-8872-4A1E-9F72-082F72252B3F.png
# 2  A1   A1  15991304-7501-4377-BE6E-1B9AF5258FC1.png
# 3  A1   A1  5CE2CB9A-C765-4240-B3D3-E352B1581A1B.png
# 4  A1   A1  26A32C19-6890-4999-A7F2-D8399A56E3B5.png

# %%
table_A1Set2 = pd.read_excel(Set2, sheet_name='A1_2')
table_A1Set2.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  27.353949  20.900657  234.443876  29.133593  21.026053  235.482104    Set4
# 1  27.083922  23.883613  227.936775  26.710900  24.300219  228.749046    Set4
# 2  28.381138  23.864621  227.502232  28.110543  24.423099  228.044558    Set4
# 3  29.827287  21.573898  233.845548  31.178476  21.287233  234.974272    Set4
# 4  27.829884  23.650678  227.613992  27.146822  24.317101  228.425452    Set4
#
#   Ref Shad                                       Img
# 0  A1   A1  2BFE464D-1D6D-46D6-99C7-4FCDC9358FEA.png
# 1  A1   A1  89D4705E-E69B-4FE0-BB8B-ED158F2155F8.png
# 2  A1   A1  9F9519D1-510E-4D8E-AE74-9911DFC3D27F.png
# 3  A1   A1  13A4FFF1-164D-4B22-B433-C4EA152F1366.png
# 4  A1   A1  89E19FAA-FD5D-4051-B0E7-B91CFDA3DADF.png

# %% [markdown]
# ###RGB

# %%
clf1 =svm.SVC(kernel='poly')

# %%
RGB_A1_Set1 = table_A1Set1

# %%
RGB_A1_Set2 = table_A1Set2

# %%
RGB_A1_Set3 = table_A1Set3

# %%
RGB_A1_Set4 = table_A1Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_A1_concat0 = pd.concat([RGB_A1_Set2,RGB_A1_Set3,RGB_A1_Set1])

# %%
RGB_A1_concat2 = RGB_A1_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A1_RGB = np.array(RGB_A1_Set4)

# %%
y_A1_RGB =  table_A1Set4.iloc[:,14:15]

# %%
y_test_A1_RGB = np.array(y_A1_RGB)

# %%
X_train_A1_RGB = np.array(RGB_A1_concat2)

# %%
y_train_A1RGB = RGB_A1_concat0.iloc[:,14:15]

# %%
y_train_A1_RGB = np.array(y_train_A1RGB)

# %%
clf1.fit(X_train_A1_RGB, y_train_A1_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_A1_RGB = clf1.predict(X_test_A1_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_A1_RGB, y_pred_A1_RGB))
# Out:
# Accuracy: 0.7675

# %% [markdown]
# ###HSV

# %%
clf2=svm.SVC(kernel='poly')

# %%
HSV_A1_Set4 = table_A1Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_A1_concat2 = RGB_A1_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A1_HSV = np.array(HSV_A1_Set4)

# %%
y_A1_HSV =  table_A1Set4.iloc[:,14:15]

# %%
y_test_A1_HSV = np.array(y_A1_RGB)

# %%
X_train_A1_HSV = np.array(HSV_A1_concat2)

# %%
y_train_A1HSV = RGB_A1_concat0.iloc[:,14:15]

# %%
y_train_A1_HSV = np.array(y_train_A1HSV)

# %%
clf2.fit(X_train_A1_HSV, y_train_A1_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_A1_HSV = clf2.predict(X_test_A1_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_A1_HSV, y_pred_A1_HSV))
# Out:
# Accuracy: 0.5325

# %% [markdown]
# ##A2

# %%
table_A2Set1 = pd.read_excel(Set1 , sheet_name='A2_1')
table_A2Set1.head()
# Out:
#       R-ref     G-ref     B-ref    R-Shad    G-Shad    B-Shad     H-ref  \
# 0  236.8857  219.6456  178.9067  240.1290  230.4967  199.8664  21.22734
# 1  236.5746  219.3545  179.3893  239.5857  229.7970  199.5082  21.18895
# 2  236.5240  219.3535  178.9860  239.6360  230.0293  199.9317  21.23943
# 3  236.4670  219.8862  179.6011  239.8989  230.6030  201.2019  21.47529
# 1  A2   A1  BA3AFF8D-AAA7-4A26-A99D-58E7730257A4.png
# 2  A2   A1  0F941597-744A-4ADE-973D-21AB168D1129.png
# 3  A2   A1  A63282AB-FC26-4DE4-8787-9276F2B800C0.png
# 4  A2   A1  D5F0E3B1-E9A0-4496-8806-ABEB0B70C533.png

# %%
table_A2Set4 = pd.read_excel(Set4, sheet_name='A2_4')
table_A2Set4.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  233.260774  227.901956  201.717150  230.029381  228.600519  211.502070
# 1  233.393231  227.774856  201.675432  229.662852  227.930038  210.893272
# 2  225.906339  220.894408  191.121175  222.150718  220.946352  200.736223
# 3  225.443389  220.425209  190.769012  221.999026  220.791088  200.795390
# 4  232.792062  227.933853  201.091957  229.445175  228.540865  210.156968
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  25.829235  34.711306  233.286665  29.192355  20.703758  230.123691    Set4
# 1  25.533155  34.890187  233.420826  28.522117  20.972892  229.728512    Set4
# 2  25.943592  39.249574  225.907232  28.622433  24.621946  222.151043    Set4
# 3  25.943511  39.176690  225.444201  28.561643  24.351757  221.999026    Set4
# 4  26.390877  34.956659  232.816492  29.944160  21.598409  229.559614    Set4
#
#   Ref Shad                                       Img
# 0  A2   A1  32311BEA-0470-4D35-AE74-307331146F6B.png
# 1  A2   A1  7F5A3DCA-19B2-4D09-8A4E-518F576D12C6.png
# 2  A2   A1  ADD7F30E-6D84-4B3A-9E24-47AD358C03B3.png
# 3  A2   A1  513F7C8E-CA13-40B5-9634-5F151E841C6B.png
# 4  A2   A1  06F92E7E-7005-426D-A897-6EB6FF43717C.png

# %% [markdown]
# ###RGB

# %%
clf3=svm.SVC(kernel='poly')

# %%
RGB_A2_Set4 = table_A2Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_A2_Set2 = table_A2Set2

# %%
RGB_A2_Set3 = table_A2Set3

# %%
RGB_A2_Set1 = table_A2Set1

# %%
RGB_A2_concat0 = pd.concat([RGB_A2_Set2,RGB_A2_Set3,RGB_A2_Set1])

# %%
RGB_A2_concat2 = RGB_A2_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A2_RGB = np.array(RGB_A2_Set4)

# %%
y_A2_RGB =  table_A2Set4.iloc[:,14:15]

# %%
y_test_A2_RGB = np.array(y_A2_RGB)

# %%
X_train_A2_RGB = np.array(RGB_A2_concat2)

# %%
y_train_A2RGB = RGB_A2_concat0.iloc[:,14:15]

# %%
y_train_A2_RGB = np.array(y_train_A2RGB)

# %%
clf3.fit(X_train_A2_RGB, y_train_A2_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_A2_RGB = clf3.predict(X_test_A2_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_A2_RGB, y_pred_A2_RGB))
# Out:
# Accuracy: 0.93

# %% [markdown]
# ###HSV

# %%
clf4=svm.SVC(kernel='poly')

# %%
HSV_A2_Set4 = table_A2Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_A2_concat2 = RGB_A2_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A2_HSV = np.array(HSV_A2_Set4)

# %%
y_A2_HSV =  table_A2Set4.iloc[:,14:15]

# %%
y_test_A2_HSV = np.array(y_A2_RGB)

# %%
X_train_A2_HSV = np.array(HSV_A2_concat2)

# %%
y_train_A2HSV = RGB_A2_concat0.iloc[:,14:15]

# %%
y_train_A2_HSV = np.array(y_train_A2HSV)

# %%
clf4.fit(X_train_A2_HSV, y_train_A2_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  27.558153  41.178557  240.781836  30.507751  21.537051  234.514974    Set3
# 1  27.548007  48.120039  230.957714  29.357520  24.215648  224.663826    Set3
# 2  28.898466  40.093418  239.119065  31.191949  20.850905  234.030111    Set3
# 3  27.797176  40.728269  236.385277  31.780943  19.974109  232.260937    Set3
# 4  27.494522  40.443146  236.178800  32.354760  19.732246  232.497038    Set3
#
#   Ref Shad                                       Img
# 0  A3   A1  DC980AD2-81DD-4EAE-80D5-0CDDA83B06E7.png
# 1  A3   A1  5D10BAC5-8F2F-4EAC-86CE-FBA2AB6F50DD.png
# 2  A3   A1  E974AE96-AD14-4660-857A-2B63C16E8EB1.png
# 3  A3   A1  16DB511D-570A-4F94-808B-93F9C47B4CE9.png
# 4  A3   A1  1035897E-D1B4-4245-BE07-6C461520AF33.png

# %%
table_A3Set4 = pd.read_excel(Set4, sheet_name='A3_4')
table_A3Set4.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  227.620242  222.732165  183.910722  224.643211  223.240808  204.516273
# 1  233.414414  229.274085  194.013716  231.174580  230.676000  213.018505
# 2  233.672916  228.515948  194.846928  231.270027  230.057788  213.578281
# 3  226.789465  221.794822  183.757406  224.543057  222.785407  204.182453
# 4  233.572843  228.452317  194.478451  231.114276  229.895463  213.453940
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  26.944079  49.071179  227.620891  28.388929  22.886048  224.664962    Set4
# 1  27.785894  43.269702  233.453778  31.177745  20.424803  231.484539    Set4
# 2  26.810324  42.559938  233.696859  29.412385  19.732570  231.363363    Set4
# 3  26.900739  48.476909  226.789627  27.672348  23.090983  224.548170    Set4
# 4  26.793848  42.842464  233.589481  29.352244  19.680708  231.193897    Set4
#
#   Ref Shad                                       Img
# 0  A3   A1  099CF1A3-858D-4BA2-A8BC-C91A564396D7.png
# 1  A3   A1  9469517A-8B99-4786-9686-2CFEE6A31CE0.png
# 2  A3   A1  25B0DFEE-A7FC-43BC-A6B7-BB7D513F07E8.png
# 3  A3   A1  12160C42-A338-4723-AF9C-E0040D3CEFF9.png
# 4  A3   A1  B37CF291-B0F8-4DAB-B072-5B8DA68A31B5.png

# %% [markdown]
# ###RGB

# %%
clf5=svm.SVC(kernel='poly')

# %%
RGB_A3_Set4 = table_A3Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_A3_Set2 = table_A3Set2

# %%
RGB_A3_Set3 = table_A3Set3

# %%
RGB_A3_Set1 = table_A3Set1

# %%
RGB_A3_concat = pd.concat([RGB_A3_Set2,RGB_A3_Set3,RGB_A3_Set1])

# %%
RGB_A3_concat2 = RGB_A3_concat.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A3_RGB = np.array(RGB_A3_Set4)

# %%
y_A3_RGB =  table_A3Set4.iloc[:,14:15]

# %%
y_test_A3_RGB = np.array(y_A3_RGB)

# %%
X_train_A3_RGB = np.array(RGB_A3_concat2)

# %%
y_train_A3RGB = RGB_A3_concat.iloc[:,14:15]

# %%
y_train_A3_RGB = np.array(y_train_A3RGB)

# %%
clf5.fit(X_train_A3_RGB, y_train_A3_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_A3_RGB = clf5.predict(X_test_A3_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_A3_RGB, y_pred_A3_RGB))
# Out:
# Accuracy: 0.8925

# %% [markdown]
# ###HSV

# %%
clf6=svm.SVC(kernel='poly')

# %%
HSV_A3_Set4 = table_A3Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_A3_concat2 = RGB_A3_concat.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A3_HSV = np.array(HSV_A3_Set4)

# %%
y_A3_HSV =  table_A3Set4.iloc[:,14:15]

# %%
y_test_A3_HSV = np.array(y_A3_RGB)

# %%
X_train_A3_HSV = np.array(HSV_A3_concat2)

# %%
y_train_A3HSV = RGB_A3_concat.iloc[:,14:15]

# %%
y_train_A3_HSV = np.array(y_train_A3HSV)

# %%
clf6.fit(X_train_A3_HSV, y_train_A3_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_A3_HSV = clf6.predict(X_test_A3_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_A3_HSV, y_pred_A3_HSV))
# Out:
# Accuracy: 0.54

# %% [markdown]
# ##A3.5

# %%
clf7=svm.SVC(kernel='poly')

# %%
table_A3_5Set1 = pd.read_excel(Set1 , sheet_name='A3.5_1')
table_A3_5Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  236.521954  209.560425  156.946676  243.394530  228.810405  193.729405
# 1  238.063794  210.368071  155.388605  244.828910  230.410437  192.981576
# 2  237.652463  210.789303  155.764873  244.605714  230.424966  193.343154
# 3  237.005763  210.512134  156.634932  243.224901  229.625436  193.792306
# 4  237.200877  211.312393  157.905284  243.624625  230.534940  195.817791
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  19.985391  85.867056  236.521954  21.287801  52.127019  243.394530    Set1
# 1  19.988394  88.619755  238.063794  21.822660  54.093905  244.828910    Set1
# 2  20.219138  87.943755  237.652463  21.876552  53.544680  244.605714    Set1
# 3  20.253632  86.534291  237.005763  21.880286  51.931743  243.224901    Set1
# 4  20.422855  85.310040  237.200877  21.935395  50.146660  243.624625    Set1
#
#     Ref Shad                                       Img
# 0  A3.5   A1  2DD07CB7-0413-41D5-BE23-51CA3C9164F5.png
# 1  A3.5   A1  F28F074F-5B54-424C-8E70-EC56E06FC3E0.png
# 2  A3.5   A1  6ABA4B94-D8B3-48BA-B1FA-6B5A081F40D1.png
# 3  A3.5   A1  6B5870DF-9D32-4295-9D0E-F1DDA4ABD18F.png
# 4  A3.5   A1  9EBCADA0-A39C-4692-B684-A967FE6F59B5.png

# %%
table_A3_5Set2 = pd.read_excel(Set2, sheet_name='A3.5_2')
table_A3_5Set2.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  230.525850  201.762276  143.723480  233.097232  215.519520  174.350296
# 1  227.598003  195.522928  133.524552  232.723237  212.633390  167.957796
# 2  230.512783  201.153965  142.168817  234.111355  215.418878  171.895463
# 3  231.764629  202.156562  142.283013  234.933447  216.170765  172.677299
# 4  231.882721  202.259963  142.745394  234.805616  216.401510  173.300219
#
#        H-ref       S-ref       V-ref     H-Shad     S-Shad      V-Shad  \
# 0  20.053811   96.170035  230.525850  21.308254  64.395341  233.097476
# 1  19.533398  105.379028  227.598003  20.546141  71.021589  232.723318
# 2  19.983037   97.871682  230.512783  21.241620  67.883370  234.112085
# 3  20.152423   98.609285  231.764629  21.052268  67.724779  234.935233
# 4  19.973135   98.174499  231.882721  21.227173  66.919000  234.806347
#
#   Setting   Ref Shad                                       Img
# 0    Set2  A3.5   A1  DD92C3DE-FED4-405C-A9BE-F6CB3CC67D3C.png
# 1    Set2  A3.5   A1  475DD7D4-D0A4-4875-8A88-515EC0BE2FEA.png
# 2    Set2  A3.5   A1  6A134D80-DECF-4205-B3F2-0FC7F87D6F47.png
# 3    Set2  A3.5   A1  3AF27BD7-16A3-47B3-A9D2-6F28AB0A73D4.png
# 4    Set2  A3.5   A1  F1DEE804-F5D7-48D6-A2AF-FB7B10C7C006.png

# %%
table_A3_5Set3 = pd.read_excel(Set3, sheet_name='A3.5_3')
table_A3_5Set3.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  234.789790  227.862511  192.009090  232.556773  231.819820  219.221816
# 1  225.381868  217.347861  174.858940  222.530395  222.311095  206.975246
# 2  225.723074  217.551497  177.828098  221.912751  222.370181  209.080188
# 3  234.848227  227.721938  192.168980  232.155182  231.702459  219.144469
# 4  234.453291  227.748722  193.671049  230.745638  231.457430  220.141547
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  28.267430  47.004870  234.865190  35.101047  15.556124  232.987988    Set3
# 1  25.473501  57.234884  225.382193  29.782891  18.370668  223.084571    Set3
# 2  25.195926  54.222222  225.726483  31.620810  15.582826  222.632010    Set3
# 3  27.598247  46.850580  234.917052  35.968834  15.483889  232.779158    Set3
# 4  28.364743  44.927279  234.552796  39.213132  13.280659  231.667965    Set3
#
#     Ref Shad                                       Img
# 0  A3.5   A1  EA18B729-21CA-4CBD-9CD9-87A230B62A73.png
# 1  A3.5   A1  6F63F3BD-AD91-4D05-A01E-F262738EC089.png
# 2  A3.5   A1  C25C23A8-8D33-471D-9F99-1D7F0A5A2256.png
# 3  A3.5   A1  C7840948-E4E4-4326-9CA7-7249FD51E66F.png
# 4  A3.5   A1  6D2686E5-1F1E-46F5-8307-2588684AE288.png

# %%
table_A3_5Set4 = pd.read_excel(Set4, sheet_name='A3.5_4')
table_A3_5Set4.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  219.071829  202.284636  153.413684  217.003165  209.154127  186.799123
# 1  218.764143  202.356140  154.260206  217.063388  209.804886  188.133755
# 2  218.561399  202.688499  154.177826  216.792874  210.099911  188.036766
# 3  220.439818  205.936206  160.073046  220.855288  214.330898  193.493385
# 4  220.497038  206.076942  160.544355  220.946514  214.425777  193.726402
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  22.449882  76.533723  219.071991  22.143495  35.567405  217.003165    Set4
# 1  22.482672  75.308011  218.764143  22.590293  34.072397  217.063388    Set4
# 2  22.737197  75.188540  218.561399  23.140005  33.866245  216.793199    Set4
# 3  23.141709  70.030923  220.442659  23.827855  31.749128  220.861781    Set4
# 4  23.040419  69.536969  220.498823  23.629170  31.591510  220.960068    Set4
#
#     Ref Shad                                       Img
# 0  A3.5   A1  59331E47-9409-4752-859C-BD69B64F2FC6.png
# 1  A3.5   A1  271B26B6-1BC4-4A50-9198-127569C8BF3D.png
# 2  A3.5   A1  101CF038-4C3A-400E-9C2C-6CC2F63DEEEF.png
# 3  A3.5   A1  4CA308BF-F5D3-47CB-A3C0-4D0D3CBD97AA.png
# 4  A3.5   A1  C05E2226-6B18-40E3-966D-02DE782F3404.png

# %% [markdown]
# ###RGB

# %%
RGB_A3_5_Set4 = table_A3_5Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_A3_5_Set2 = table_A3_5Set2

# %%
RGB_A3_5_Set3 = table_A3_5Set3

# %%
RGB_A3_5_Set1 = table_A3_5Set1

# %%
RGB_A3_5_concat0 = pd.concat([RGB_A3_5_Set2,RGB_A3_5_Set3,RGB_A3_5_Set1])

# %%
RGB_A3_5_concat2 = RGB_A3_5_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A3_5_RGB = np.array(RGB_A3_5_Set4)

# %%
y_A3_5_RGB =  table_A3_5Set4.iloc[:,14:15]

# %%
y_test_A3_5_RGB = np.array(y_A3_5_RGB)

# %%
X_train_A3_5_RGB = np.array(RGB_A3_5_concat2)

# %%
y_train_A3_5RGB = RGB_A3_5_concat0.iloc[:,14:15]

# %%
y_train_A3_5_RGB = np.array(y_train_A3_5RGB)

# %%
clf7.fit(X_train_A3_5_RGB, y_train_A3_5_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_A3_5_RGB = clf7.predict(X_test_A3_5_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_A3_5_RGB, y_pred_A3_5_RGB))
# Out:
# Accuracy: 0.355

# %% [markdown]
# ###HSV

# %%
clf8=svm.SVC(kernel='poly')

# %%
HSV_A3_5_Set4 = table_A3_5Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_A3_5_concat2 = RGB_A3_5_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A3_5_HSV = np.array(HSV_A3_5_Set4)

# %%
y_A3_5_HSV =  table_A3_5Set1.iloc[:,14:15]

# %%
y_test_A3_5_HSV = np.array(y_A3_5_RGB)

# %%
X_train_A3_5_HSV = np.array(HSV_A3_5_concat2)

# %%
y_train_A3_5HSV = RGB_A3_5_concat0.iloc[:,14:15]

# %%
y_train_A3_5_HSV = np.array(y_train_A3_5HSV)

# %%
clf8.fit(X_train_A3_5_HSV, y_train_A3_5_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_A3_5_HSV = clf8.predict(X_test_A3_5_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_A3_5_HSV, y_pred_A3_5_HSV))
# Out:
# Accuracy: 0.23875

# %% [markdown]
# ##A4

# %%
table_A4Set1 = pd.read_excel(Set1 , sheet_name='A4_1')
table_A4Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  231.225793  207.225306  163.194708  242.074426  231.760409  208.267186
# 1  231.522523  206.851798  162.085870  241.816817  230.490950  205.902524
# 2  230.894895  204.879961  159.071342  241.838000  229.495820  203.721208
# 3  231.246084  206.003815  159.512296  241.745638  229.942699  203.285204
# 4  232.597760  207.029868  160.616995  242.765685  230.498742  204.188783
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  19.478370  75.143495  231.225793  20.980440  35.674539  242.074507    Set1
# 1  19.409382  76.557341  231.522523  20.550686  37.913075  241.816817    Set1
# 2  19.183183  79.405000  230.894895  20.298190  40.262803  241.838000    Set1
# 3  19.544761  79.192517  231.246084  20.893028  40.626410  241.745638    Set1
# 4  19.446636  78.970863  232.597760  20.506534  40.561237  242.765685    Set1
#
#   Ref Shad                                       Img
# 0  A4   A1  E3173A1F-D34A-4D28-928B-E1C32CF79872.png
# 1  A4   A1  013F1BC6-5EF5-4A49-8F01-69FB54E775C3.png
# 2  A4   A1  0F4BD91E-9F4C-408D-BD77-1A2D48FD0758.png
# 3  A4   A1  C3FDAEEA-FA70-4C39-AF06-F3A68D515336.png
# 4  A4   A1  9C8F8D57-3A59-4F0F-8F7E-9F81D3456B62.png

# %%
table_A4Set2 = pd.read_excel(Set2, sheet_name='A4_2')
table_A4Set2.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  23.870546  59.034494  211.041230  24.488516  22.934177  221.542813    Set4
# 1  23.771041  64.070692  207.663096  26.216784  24.654411  215.775262    Set4
# 2  24.316857  59.150069  210.987988  26.669994  22.567324  220.781836    Set4
# 3  24.414252  59.234153  210.889619  26.324487  22.391040  220.337878    Set4
# 4  23.742878  63.809269  207.636555  26.232692  24.316046  216.133755    Set4
#
#   Ref Shad                                       Img
# 0  A4   A1  C6D0A6B4-EAD1-4C5F-9E6B-CE5E0923BCF0.png
# 1  A4   A1  A3B3B5C2-1901-4D2C-8309-010408F66705.png
# 2  A4   A1  4C428E15-84C8-4D96-BD24-DC9969741560.png
# 3  A4   A1  91F5B0B5-A4E2-4073-A924-AC7A2ECB236F.png
# 4  A4   A1  606F71D4-DD41-4252-B152-C019C53AE874.png

# %% [markdown]
# ###RGB

# %%
clf9=svm.SVC(kernel='poly')

# %%
RGB_A4_Set4 = table_A4Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_A4_Set2 = table_A4Set2

# %%
RGB_A4_Set3 = table_A4Set3

# %%
RGB_A4_Set1 = table_A4Set1

# %%
RGB_A4_concat0 = pd.concat([RGB_A4_Set2,RGB_A4_Set3,RGB_A4_Set1])

# %%
RGB_A4_concat2 = RGB_A4_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A4_RGB = np.array(RGB_A4_Set4)

# %%
y_A4_RGB =  table_A4Set4.iloc[:,14:15]

# %%
y_test_A4_RGB = np.array(y_A4_RGB)

# %%
X_train_A4_RGB = np.array(RGB_A4_concat2)

# %%
y_train_A4_RGB = RGB_A4_concat0.iloc[:,14:15]

# %%
y_train_A4_RGB = np.array(y_train_A4_RGB)

# %%
clf9.fit(X_train_A4_RGB, y_train_A4_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_A4_RGB = clf9.predict(X_test_A4_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_A4_RGB, y_pred_A4_RGB))
# Out:
# Accuracy: 0.7775

# %% [markdown]
# ###HSV

# %%
clf10=svm.SVC(kernel='poly')

# %%
HSV_A4_Set4 = table_A4Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_A4_concat2 = RGB_A4_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_A4_HSV = np.array(HSV_A4_Set4)

# %%
y_A4_HSV =  table_A4Set4.iloc[:,14:15]

# %%
y_test_A4_HSV = np.array(y_A4_RGB)

# %%
X_train_A4_HSV = np.array(HSV_A4_concat2)

# %%
y_train_A4HSV = RGB_A4_concat0.iloc[:,14:15]

# %%
y_train_A4_HSV = np.array(y_train_A4HSV)

# %%
clf10.fit(X_train_A4_HSV, y_train_A4_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_A4_HSV = clf10.predict(X_test_A4_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_A4_HSV, y_pred_A4_HSV))
# Out:
# Accuracy: 0.47

# %% [markdown]
# #BB

# %% [markdown]
# ##B1

# %%
table_B1Set1 = pd.read_excel(Set1 , sheet_name='B1_1')
table_B1Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  234.492330  224.346725  192.380489  240.971025  228.479507  194.079052
# 1  230.950735  219.930769  185.020372  237.675189  224.627465  187.591186
# 2  235.713497  225.486892  193.015015  242.104780  229.496469  195.054216
# 3  234.890350  224.554500  191.764467  240.631686  228.004545  192.949923
# 4  231.349403  220.936531  187.469361  237.432595  225.213132  191.017937
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0
head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  224.326759  221.108839  203.850093  219.784514  213.464573  190.317344
# 1  229.503693  229.352812  212.427969  226.453453  222.675919  197.858128
# 2  222.500609  223.042529  201.223521  218.539891  215.885805  187.822985
# 3  228.807077  230.561156  211.762763  226.170684  224.499148  197.844493
# 4  229.235695  230.981089  211.935720  225.856911  224.164516  197.202013
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  25.347537  23.311663  224.326759  23.720640  34.241863  219.784514    Set4
# 1  30.464816  19.511241  229.940833  26.107134  32.314666  226.461570    Set4
# 2  30.988637  25.075075  223.184888  27.346563  35.863891  218.539891    Set4
# 3  33.748235  20.870303  230.563022  28.464978  32.052431  226.188865    Set4
# 4  33.622271  21.117036  230.984417  28.327003  32.428212  225.861781    Set4
#
#   Ref Shad                                       Img
# 0  B1   A1  FE8C5C61-E1C3-43CD-89CA-1CC9F2F64918.png
# 1  B1   A1  D3A831B0-6702-4ED8-BCD2-DF3E93AE96AA.png
# 2  B1   A1  8A8341B2-51DF-4C76-9E21-423D884578F9.png
# 3  B1   A1  73445C43-E3BF-421B-9A97-1F1182DFFF9A.png
# 4  B1   A1  56FEB49F-EF2D-4F39-A5BC-CCD039F7C855.png

# %% [markdown]
# ###RGB

# %%
clf11=svm.SVC(kernel='poly')

# %%
RGB_B1_Set4 = table_B1Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_B1_Set2 = table_B1Set2

# %%
RGB_B1_Set3 = table_B1Set3

# %%
RGB_B1_Set1 = table_B1Set1

# %%
RGB_B1_concat0 = pd.concat([RGB_B1_Set2,RGB_B1_Set3,RGB_B1_Set1])

# %%
RGB_B1_concat2 = RGB_B1_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_B1_RGB = np.array(RGB_B1_Set4)

# %%
y_B1_RGB =  table_B1Set4.iloc[:,14:15]

# %%
y_test_B1_RGB = np.array(y_B1_RGB)

# %%
X_train_B1_RGB = np.array(RGB_B1_concat2)

# %%
y_train_B1RGB = RGB_B1_concat0.iloc[:,14:15]

# %%
y_train_B1_RGB = np.array(y_train_B1RGB)

# %%
clf11.fit(X_train_B1_RGB, y_train_B1_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_B1_RGB = clf11.predict(X_test_B1_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_B1_RGB, y_pred_B1_RGB))
# Out:
# Accuracy: 0.57375

# %% [markdown]
# ###HSV

# %%
clf12=svm.SVC(kernel='poly')

# %%
HSV_B1_Set4 = table_B1Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_B1_concat2 = RGB_B1_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_B1_HSV = np.array(HSV_B1_Set4)

# %%
y_B1_HSV =  table_B1Set4.iloc[:,14:15]

# %%
y_test_B1_HSV = np.array(y_B1_RGB)

# %%
X_train_B1_HSV = np.array(HSV_B1_concat2)

# %%
y_train_B1HSV = RGB_B1_concat0.iloc[:,14:15]

# %%
y_train_B1_HSV = np.array(y_train_B1HSV)

# %%
clf12.fit(X_train_B1_HSV, y_train_B1_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_B1_HSV = clf12.predict(X_test_B1_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_B1_HSV, y_pred_B1_HSV))
# Out:
# Accuracy: 0.37625

# %% [markdown]
# ##B2

# %%
table_B2Set1 = pd.read_excel(Set1 , sheet_name='B2_1')
table_B2Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  31.250061  30.428699  235.506209  31.743933  21.484052  232.710413    Set3
# 1  31.428780  30.509699  235.308579  32.006006  21.132457  232.931256    Set3
# 2  31.299489  30.273273  235.767064  32.020534  21.183427  233.293807    Set3
# 3  31.452074  30.069800  235.762682  31.844737  20.979466  233.522928    Set3
# 4  30.956416  30.753591  235.073858  32.141303  21.354841  232.527230    Set3
#
#   Ref Shad                                       Img
# 0  B2   A1  250FC647-07B6-4795-B3EF-E2E97F609E10.png
# 1  B2   A1  829D716F-ABCB-494F-942F-92D985E969FC.png
# 2  B2   A1  31E84E1C-8996-478A-8C5B-DEB651BD8B7B.png
# 3  B2   A1  1096FB39-AC69-47B0-A58C-D5EAF4178133.png
# 4  B2   A1  561D36AA-0D94-45A1-88BE-C705DA5140C7.png

# %%
table_B2Set4 = pd.read_excel(Set4, sheet_name='B2_4')
table_B2Set4.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  230.024024  223.702053  196.546547  225.821930  219.226930  200.151368
# 1  221.614236  222.497930  181.940752  216.772583  217.695642  185.979060
# 2  224.173687  218.290561  185.797663  219.794984  213.752131  191.268079
# 3  223.656927  219.788491  184.318318  218.983524  214.888727  188.910884
# 4  223.816005  220.383086  184.133268  218.352406  216.356383  189.309715
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  24.611152  37.253389  230.032384  23.084571  29.186754  225.827043    Set4
# 1  30.883695  46.488272  222.497930  30.923058  37.207370  217.733220    Set4
# 2  25.613505  43.686308  224.173687  23.862349  33.074345  219.794984    Set4
# 3  26.974759  44.941239  223.656927  25.869816  34.984498  218.983524    Set4
# 4  27.434948  45.237887  223.816005  28.003977  33.867137  218.352406    Set4
#
#   Ref Shad                                       Img
# 0  B2   A1  5B0F9488-7F08-4BCE-A32E-55154984960A.png
# 1  B2   A1  0E6453D8-FF6B-407E-97CD-CD738C98FDF2.png
# 2  B2   A1  080A292F-0B63-4933-A09A-199874BA4870.png
# 3  B2   A1  3638FEC4-42D0-4824-AD26-F7E587220698.png
# 4  B2   A1  8D6E4CD1-034D-487B-80CB-3AE03EE1D093.png

# %% [markdown]
# ###RGB

# %%
clf13=svm.SVC(kernel='poly')

# %%
RGB_B2_Set4 = table_B2Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_B2_Set2 = table_B2Set2

# %%
RGB_B2_Set3 = table_B2Set3

# %%
RGB_B2_Set1 = table_B2Set1

# %%
RGB_B2_concat0 = pd.concat([RGB_B2_Set2,RGB_B2_Set3,RGB_B2_Set1])

# %%
RGB_B2_concat2 = RGB_B2_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_B2_RGB = np.array(RGB_B2_Set4)

# %%
y_B2_RGB =  table_B2Set4.iloc[:,14:15]

# %%
y_test_B2_RGB = np.array(y_B2_RGB)

# %%
X_train_B2_RGB = np.array(RGB_B2_concat2)

# %%
y_train_B2RGB = RGB_B2_concat0.iloc[:,14:15]

# %%
y_train_B2_RGB = np.array(y_train_B2RGB)

# %%
clf13.fit(X_train_B2_RGB, y_train_B2_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_B2_RGB = clf13.predict(X_test_B2_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_B2_RGB, y_pred_B2_RGB))
# Out:
# Accuracy: 0.55375

# %% [markdown]
# ###HSV

# %%
clf14=svm.SVC(kernel='poly')

# %%
HSV_B2_Set4 = table_B2Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_B2_concat2 = RGB_B2_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_B2_HSV = np.array(HSV_B2_Set4)

# %%
y_B2_HSV =  table_B2Set4.iloc[:,14:15]

# %%
y_test_B2_HSV = np.array(y_B2_RGB)

# %%
X_train_B2_HSV = np.array(HSV_B2_concat2)

# %%
y_train_B2HSV = RGB_B2_concat0.iloc[:,14:15]

# %%
y_train_B2_HSV = np.array(y_train_B2HSV)

# %%
clf14.fit(X_train_B2_HSV, y_train_B2_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_B2_HSV = clf14.predict(X_test_B2_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_B2_HSV, y_pred_B2_HSV))
# Out:
# Accuracy: 0.46

# %% [markdown]
# ##B3

# %%
table_B3Set1 = pd.read_excel(Set1 , sheet_name='B3_1')
table_B3Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  237.494684  208.533398  158.263534  241.452723  220.398507  187.469199
# 1  233.706923  204.090821  154.434867  238.934908  217.925655  185.930119
# 2  237.440711  210.784839  160.240646  241.434056  222.211996  189.821281
# 3  237.416768  209.644509  160.474556  241.624219  221.237481  189.495820
# 4  236.176041  208.513270  158.338609  240.525931  220.440386  187.916484
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  18.991072  85.135379  237.494684  18.275546  57.117279  241.452885    Set1
# 1  18.785732  86.572924  233.706923  18.004383  56.653843  238.934908    Set1
# 2  19.770554  83.044558  237.440711  18.910397  54.597922  241.434705    Set1
# 3  19.218895  82.745394  237.416768  18.240808  55.121256  241.624219    Set1
# 4  19.459946  84.152423  236.176041  18.561643  55.879799  240.526581    Set1
#
#   Ref Shad                                       Img
# 0  B3   A1  768ECDBF-055D-4AF1-9FB6-59F1D54C18F2.png
# 1  B3   A1  A2B09945-ABB4-4B6C-8880-C0859637306B.png
# 2  B3   A1  5C57C433-024F-4E4A-B661-2A33A270EE9D.png
# 3  B3   A1  6D8E199E-9FF6-46BF-A7CA-D491A179F0EB.png
# 4  B3   A1  09286B35-9904-4EE4-8AF2-92443DF8DA7D.png

# %%
table_B3Set2 = pd.read_excel(Set2, sheet_name='B3_2')
table_B3Set2.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  234.164110  212.604496  155.235046  235.183670  220.016395  179.384628
# 1  233.094960  210.277169  153.528366  234.479182  218.009983  176.335525
# 2  232.942050  210.142846  153.425290  234.265725  217.921273  176.164841
# 3  234.085626  211.622677  152.596056  235.249249  218.894814  176.391283
# 4  231.313449  208.378297  151.554500  232.952601  216.453697  174.120445
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  21.885724  86.109894  234.164922  22.018018  60.636637  235.186105    Set2
# 1  21.610584  87.151855  233.095934  21.839542  63.337554  234.480399    Set2
# 2  21.525444  87.159078  232.942212  21.945621  63.358981  234.266943    Set2
# 3  21.800666  88.912101  234.085870  21.993832  63.888483  235.250548    Set2
# 4  21.619511  88.035143  231.313530  21.910640  64.515380  232.953088    Set2
#
#   Ref Shad                                       Img
# 0  B3   A1  8E815009-4D5A-4F6E-B73E-3F02EEDF518E.png
# 1  B3   A1  71FB6161-2220-4F52-9DB9-988BEA1E6318.png
# 2  B3   A1  CE22D8CA-7FD1-4E9E-9A9A-6C3591E3B041.png
# 3  B3   A1  9311AA58-DD49-4827-BE81-DE9122D40F36.png
# 4  B3   A1  706F5A48-1CDB-468B-A380-D9DBE49855CB.png

# %%
table_B3Set3 = pd.read_excel(Set3, sheet_name='B3_3')
table_B3Set3.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  237.340313  233.514569  191.863729  233.376674  234.243649  215.575116
# 1  237.545978  233.754160  192.734031  233.217758  233.586884  215.566431
# 2  237.174336  233.405243  192.453372  233.155020  234.003246  215.817385
# 3  237.443146  233.671131  192.249980  232.829397  233.345264  215.205097
# 4  237.280497  233.369207  192.365311  233.808538  233.826719  215.648486
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  28.852122  49.186511  237.413927  32.288045  20.739226  234.519033    Set3
# 1  29.089847  48.474231  237.632822  31.926873  20.244055  233.996023    Set3
# 2  28.720802  48.429998  237.245110  32.327246  20.171820  234.232124    Set3
# 3  28.985066  48.897086  237.518546  31.906501  20.323513  233.698401    Set3
# 4  28.871033  48.647512  237.364094  31.126775  20.505560  234.371967    Set3
#
#   Ref Shad                                       Img
# 0  B3   A1  D30CE1BD-7348-4D4B-8B2A-9CF508F40709.png
# 1  B3   A1  A3174F21-0003-438F-AB9B-C9E9E4403930.png
# 2  B3   A1  F6329A93-CE40-40BD-82AD-EE38250C7659.png
# 3  B3   A1  0EA3962C-C625-411B-83E6-FE457309A3FA.png
# 4  B3   A1  EC8C9E12-CC68-4397-BBD7-6F464DD8A7F6.png

# %%
table_B3Set4 = pd.read_excel(Set4, sheet_name='B3_4')
table_B3Set4.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  230.465141  223.522117  184.131726  227.858453  223.376025  206.984660
# 1  222.085058  217.052268  162.522604  218.049834  216.417904  188.949030
# 2  229.628277  225.348430  177.526905  226.590861  225.277494  200.886454
# 3  229.953413  223.214349  178.450856  227.699375  223.336742  202.377810
# 4  229.970213  224.270920  178.704894  227.796283  224.925737  202.630793
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  25.966318  51.586560  230.474718  27.394692  23.726159  227.938560    Set4
# 1  27.837757  68.419690  222.085058  28.368071  34.025810  218.049834    Set4
# 2  27.939615  58.220518  229.655953  30.371236  29.406298  226.738982    Set4
# 3  26.221167  57.464086  229.960555  25.837026  28.696534  227.734275    Set4
# 4  27.078484  57.181803  229.984498  28.688012  28.592241  227.916971    Set4
#
#   Ref Shad                                       Img
# 0  B3   A1  5C22556A-CB1C-49A8-B0F9-3013F60CF097.png
# 1  B3   A1  AEB14259-1749-43ED-901D-F78CF34D6098.png
# 2  B3   A1  0D6EAE6C-73F2-4F11-86DF-9A77825BE847.png
# 3  B3   A1  214213DB-44A4-43C8-8270-BDECBDE6838F.png
# 4  B3   A1  28A87DF6-4327-4573-AB9A-73CB7077ED8E.png

# %% [markdown]
# ###RGB

# %%
clf15=svm.SVC(kernel='poly')

# %%
RGB_B3_Set4 = table_B3Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_B3_Set2 = table_B3Set2

# %%
RGB_B3_Set3 = table_B3Set3

# %%
RGB_B3_Set1 = table_B3Set1

# %%
RGB_B3_concat0 = pd.concat([RGB_B3_Set2,RGB_B3_Set3,RGB_B3_Set1])

# %%
RGB_B3_concat2 = RGB_B3_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_B3_RGB = np.array(RGB_B3_Set4)

# %%
y_B3_RGB =  table_B3Set4.iloc[:,14:15]

# %%
y_test_B3_RGB = np.array(y_B3_RGB)

# %%
X_train_B3_RGB = np.array(RGB_B3_concat2)

# %%
y_train_B3RGB = RGB_B3_concat0.iloc[:,14:15]

# %%
y_train_B3_RGB = np.array(y_train_B3RGB)

# %%
clf15.fit(X_train_B3_RGB, y_train_B3_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_B3_RGB = clf15.predict(X_test_B3_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_B3_RGB, y_pred_B3_RGB))
# Out:
# Accuracy: 0.76625

# %% [markdown]
# ###HSV

# %%
clf16=svm.SVC(kernel='poly')

# %%
HSV_B3_Set4 = table_B3Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_B3_concat2 = RGB_B3_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_B3_HSV = np.array(HSV_B3_Set4)

# %%
y_B3_HSV =  table_B3Set4.iloc[:,14:15]

# %%
y_test_B3_HSV = np.array(y_B3_RGB)

# %%
X_train_B3_HSV = np.array(HSV_B3_concat2)

# %%
y_train_B3HSV = RGB_B3_concat0.iloc[:,14:15]

# %%
y_train_B3_HSV = np.array(y_train_B3HSV)

# %%
clf16.fit(X_train_B3_HSV, y_train_B3_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_B3_HSV = clf16.predict(X_test_B3_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_B3_HSV, y_pred_B3_HSV))
# Out:
# Accuracy: 0.41625

# %% [markdown]
# ##B4

# %%
table_B4Set1 = pd.read_excel(Set1 , sheet_name='B4_1')
table_B4Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  238.309228  213.735573  158.551741  242.479344  228.752942  196.386495
# 1  236.844574  213.760815  162.983281  241.450207  229.018586  201.484944
# 2  233.043178  209.123042  156.565863  239.474880  226.332116  198.275627
# 3  233.025485  209.200308  156.447853  239.889619  226.524227  198.212483
# 4  236.346482  213.261992  162.219219  241.479994  228.823229  200.937586
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  20.967779  85.414577  238.309228  21.096258  48.553202  242.479344    Set1
# 1  20.789546  79.582907  236.844574  20.665287  42.306387  241.450207    Set1
# 2  20.866001  83.728188  233.043178  20.369288  43.937343  239.474880    Set1
# 3  20.887590  83.860644  233.025485  20.308498  44.375213  239.889619    Set1
# 4  20.822579  80.041474  236.346482  20.604253  42.891080  241.479994    Set1
#
#   Ref Shad                                       Img
# 0  B4   A1  34B2D0A4-AE20-440B-976D-34704AC67DBF.png
# 1  B4   A1  749D68C6-4CBE-4281-936D-2E903F24C84B.png
# 2  B4   A1  FF438080-DFCE-4992-80C7-BC7FD4258D18.png
# 3  B4   A1  94EA0AEE-7090-4878-B886-C6D839442A90.png
# 4  B4   A1  1F086831-AF5B-4D7E-8E33-15C8CE2CF0B7.png

# %%
table_B4Set2 = pd.read_excel(Set2, sheet_name='B4_2')
table_B4Set2.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  232.498336  207.651733  143.646457  234.848876  218.742878  175.733463
# 1  232.012255  206.596056  144.686714  235.169467  218.896762  176.088223
# 2  233.085302  207.662365  145.572113  235.375132  218.588020  176.433650
# 3  233.319698  208.411330  145.859833  236.193328  220.045045  177.213213
# 4  233.285853  208.220842  145.567730  235.652057  219.679328  176.805373
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  21.777291  97.613262  232.501826  22.051782  64.264670  234.849363    Set2
# 1  21.350864  96.138869  232.014934  22.053973  64.141547  235.170035    Set2
# 2  21.370911  95.895544  233.087006  21.829397  63.936775  235.376187    Set2
# 3  21.604983  95.768363  233.323350  22.068095  63.769986  236.194059    Set2
# 4  21.447285  96.041880  233.286259  22.089928  63.743852  235.652220    Set2
#
#   Ref Shad                                       Img
drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_B4_Set2 = table_B4Set2

# %%
RGB_B4_Set3 = table_B4Set3

# %%
RGB_B4_Set1 = table_B4Set1

# %%
RGB_B4_concat0 = pd.concat([RGB_B4_Set2,RGB_B4_Set3,RGB_B4_Set1])

# %%
RGB_B4_concat2 = RGB_B4_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_B4_RGB = np.array(RGB_B4_Set4)

# %%
y_B4_RGB =  table_B4Set4.iloc[:,14:15]

# %%
y_test_B4_RGB = np.array(y_B4_RGB)

# %%
X_train_B4_RGB = np.array(RGB_B4_concat2)

# %%
y_train_B4RGB = RGB_B4_concat0.iloc[:,14:15]

# %%
y_train_B4_RGB = np.array(y_train_B4RGB)

# %%
clf17.fit(X_train_B4_RGB, y_train_B4_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_B4_RGB = clf17.predict(X_test_B4_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_B4_RGB, y_pred_B4_RGB))
# Out:
# Accuracy: 0.53875

# %% [markdown]
# ###HSV

# %%
clf18=svm.SVC(kernel='poly')

# %%
HSV_B4_Set4 = table_B4Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_B4_concat2 = RGB_B4_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_B4_HSV = np.array(HSV_B4_Set4)

# %%
y_B4_HSV =  table_B4Set4.iloc[:,14:15]

# %%
y_test_B4_HSV = np.array(y_B4_RGB)

# %%
X_train_B4_HSV = np.array(HSV_B4_concat2)

# %%
y_train_B4HSV = RGB_B4_concat0.iloc[:,14:15]

# %%
y_train_B4_HSV = np.array(y_train_B4HSV)

# %%
clf18.fit(X_train_B4_HSV, y_train_B4_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_B4_HSV = clf18.predict(X_test_B4_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_B4_HSV, y_pred_B4_HSV))
# Out:
# Accuracy: 0.2875

# %% [markdown]
# #CC

# %% [markdown]
# ##C1

# %%
table_C1Set1 = pd.read_excel(Set1 , sheet_name='C1_1')
table_C1Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  234.238860  218.539810  178.142602  243.539080  231.739794  197.517734
# 1  234.682574  218.671942  177.768363  243.879555  232.024673  197.326191
# 2  235.917945  220.763169  181.410600  244.233991  233.220355  201.094716
# 3  235.482266  220.350621  180.769093  244.104943  232.777128  199.619836
# 4  232.222628  217.325623  178.042367  241.885561  231.516192  200.039283
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  21.850012  61.156805  234.238860  22.509942  48.325461  243.546952    Set1
# 1  21.797257  61.944242  234.682574  22.541596  48.810892  243.883289    Set1
# 2  21.865595  58.999270  235.917945  22.687607  45.175229  244.242675    Set1
# 3  21.922896  59.314179  235.482266  22.532668  46.583557  244.107540    Set1
# 4  21.924763  59.560831  232.222628  22.896193  44.281146  241.899602    Set1
#
#   Ref Shad                                       Img
# 0  C1   A1  998EA81C-77D0-4357-9197-D7AEAAAE4F91.png
# 1  C1   A1  C69EF426-D68B-4503-AFC0-A62E37CCB172.png
# 2  C1   A1  95C4078C-AD0D-4394-BCF6-9C2E1E7C2219.png
# 3  C1   A1  770F3E42-0415-48C8-AE28-664827DCDAAE.png
# 4  C1   A1  AFD98982-91EB-4E2A-BEA8-8FDCCC8F33E1.png

# %%
table_C1Set2 = pd.read_excel(Set2, sheet_name='C1_2')
table_C1Set2.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0
# 0  C1   A1  2CF6DEF9-DF65-4D3E-BEC7-C1664402B848.png
# 1  C1   A1  D8408792-B96F-425D-B030-680398046CC9.png
# 2  C1   A1  A142A91A-E63C-40DA-A92E-5F3C75892CCC.png
# 3  C1   A1  B0BB3A91-5BC2-4617-8DCD-521894FD9820.png
# 4  C1   A1  B072BB25-1641-4167-A1A0-0570DB6D6C4B.png

# %% [markdown]
# ###RGB

# %%
clf19=svm.SVC(kernel='poly')

# %%
RGB_C1_Set4 = table_C1Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_C1_Set2 = table_C1Set2

# %%
RGB_C1_Set3 = table_C1Set3

# %%
RGB_C1_Set1 = table_C1Set1

# %%
RGB_C1_concat0 = pd.concat([RGB_C1_Set2,RGB_C1_Set3,RGB_C1_Set1])

# %%
RGB_C1_concat2 = RGB_B1_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_C1_RGB = np.array(RGB_C1_Set4)

# %%
y_C1_RGB =  table_C1Set4.iloc[:,14:15]

# %%
y_test_C1_RGB = np.array(y_C1_RGB)

# %%
X_train_C1_RGB = np.array(RGB_C1_concat2)

# %%
y_train_C1RGB = RGB_C1_concat0.iloc[:,14:15]

# %%
y_train_C1_RGB = np.array(y_train_C1RGB)

# %%
clf19.fit(X_train_C1_RGB, y_train_C1_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_C1_RGB = clf19.predict(X_test_C1_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_C1_RGB, y_pred_C1_RGB))
# Out:
# Accuracy: 0.09625

# %% [markdown]
# ###HSV

# %%
clf20=svm.SVC(kernel='poly')

# %%
HSV_C1_Set4 = table_C1Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_C1_concat2 = RGB_C1_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_C1_HSV = np.array(HSV_C1_Set4)

# %%
y_C1_HSV =  table_C1Set4.iloc[:,14:15]

# %%
y_test_C1_HSV = np.array(y_C1_RGB)

# %%
X_train_C1_HSV = np.array(HSV_C1_concat2)

# %%
y_train_C1HSV = RGB_C1_concat0.iloc[:,14:15]

# %%
y_train_C1_HSV = np.array(y_train_C1HSV)

# %%
clf20.fit(X_train_C1_HSV, y_train_C1_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_C1_HSV = clf20.predict(X_test_C1_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_C1_HSV, y_pred_C1_HSV))
# Out:
# Accuracy: 0.2675

# %% [markdown]
# ##C2

# %%
table_C2Set1 = pd.read_excel(Set1 , sheet_name='C2_1')
table_C2Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  228.128399  209.481617  168.929551  238.900982  227.335687  196.292022
# 1  232.343803  214.231069  173.598328  241.553040  229.825258  198.621135
# 2  227.926467  209.045857  167.911290  239.013473  227.020615  195.775830
# 3  228.438276  209.707329  168.904472  239.703109  227.941320  196.619106
# 4  231.572600  213.134729  171.677786  241.126532  228.892541  196.361902
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  20.629007  66.230257  228.128399  21.892298  45.558883  238.900982    Set1
# 1  20.953413  64.534453  232.343803  21.823553  45.385521  241.553040    Set1
# 2  20.735573  67.206233  227.926467  21.711874  46.204772  239.013473    Set1
# 3  20.693369  66.508563  228.438276  21.818440  45.907313  239.703109    Set1
# 4  20.992777  66.004464  231.572600  21.846035  47.391608  241.126532    Set1
#
#   Ref Shad                                       Img
# 0  C2   A1  94B8BCF4-0790-415E-94D6-F74A6D812F9C.png
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  24.837026  50.509942  214.223196  24.576820  32.089847  219.823472    Set4
# 1  26.587615  50.842789  212.681601  28.227579  32.987501  217.632335    Set4
# 2  28.391770  42.694262  221.243406  28.135784  28.562130  225.164110    Set4
# 3  30.524146  43.355409  220.524795  31.154371  29.803425  225.041880    Set4
# 4  27.002110  50.616346  212.290399  29.156318  32.942537  217.552471    Set4
#
#   Ref Shad                                       Img
# 0  C2   A1  97434DCB-317D-460E-B141-4F5F00BD8237.png
# 1  C2   A1  86674BAB-7B95-47B9-B2F4-6A08EA9A553C.png
# 2  C2   A1  36D924E3-369D-4810-8013-7F212B48F6E7.png
# 3  C2   A1  7656ABAF-7260-4953-A918-AB1E537D8E13.png
# 4  C2   A1  19D7369E-892D-44FC-A9F2-7C097487F05A.png

# %% [markdown]
# ###RGB

# %%
clf21=svm.SVC(kernel='poly')

# %%
RGB_C2_Set4 = table_C2Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_C2_Set2 = table_C2Set2

# %%
RGB_C2_Set3 = table_C2Set3

# %%
RGB_C2_Set1 = table_C2Set1

# %%
RGB_C2_concat0 = pd.concat([RGB_C2_Set2,RGB_C2_Set3,RGB_C2_Set1])

# %%
RGB_C2_concat2 = RGB_C2_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_C2_RGB = np.array(RGB_C2_Set4)

# %%
y_C2_RGB =  table_C2Set4.iloc[:,14:15]

# %%
y_test_C2_RGB = np.array(y_B2_RGB)

# %%
X_train_C2_RGB = np.array(RGB_C2_concat2)

# %%
y_train_C2RGB = RGB_C2_concat0.iloc[:,14:15]

# %%
y_train_C2_RGB = np.array(y_train_C2RGB)

# %%
clf21.fit(X_train_C2_RGB, y_train_C2_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_C2_RGB = clf21.predict(X_test_C2_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_C2_RGB, y_pred_C2_RGB))
# Out:
# Accuracy: 0.8225

# %% [markdown]
# ###HSV

# %%
clf22=svm.SVC(kernel='poly')

# %%
HSV_C2_Set4 = table_C2Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_C2_concat2 = RGB_C2_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_C2_HSV = np.array(HSV_C2_Set4)

# %%
y_C2_HSV =  table_C2Set4.iloc[:,14:15]

# %%
y_test_C2_HSV = np.array(y_C2_RGB)

# %%
X_train_C2_HSV = np.array(HSV_C2_concat2)

# %%
y_train_C2HSV = RGB_C2_concat0.iloc[:,14:15]

# %%
y_train_C2_HSV = np.array(y_train_C2HSV)

# %%
clf22.fit(X_train_C2_HSV, y_train_C2_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_C2_HSV = clf22.predict(X_test_C2_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_C2_HSV, y_pred_C2_HSV))
# Out:
# Accuracy: 0.3075

# %% [markdown]
# ##C3

# %%
table_C3Set1 = pd.read_excel(Set1 , sheet_name='C3_1')
table_C3Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  228.339177  207.544112  163.680870  239.537619  227.646376  195.415470
# 1  228.171577  207.106891  161.981738  238.811460  226.681438  193.663014
# 2  228.786219  207.199821  161.594432  239.737765  227.060791  193.406136
# 3  225.123448  203.137570  156.810730  236.348592  224.091226  189.985715
# 4  228.860807  207.235371  160.406704  239.286665  226.509293  191.597111
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0
head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  199.311338  188.579742  151.778265  214.126207  208.775586  187.712118
# 1  199.714471  191.414739  146.359549  214.158185  210.944647  183.051132
# 2  209.306063  203.118416  163.367746  219.686714  218.865758  190.291535
# 3  209.418310  204.265401  163.993426  219.638422  220.089197  190.624056
# 4  198.527636  192.259395  144.755539  212.014528  211.983605  180.581365
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  23.025160  60.839948  199.311338  23.727295  31.535103  214.126207    Set4
# 1  25.632984  68.205422  199.714471  26.791007  37.068826  214.158835    Set4
# 2  30.893190  57.990748  209.607743  30.091632  34.675757  219.921922    Set4
# 3  31.432757  57.436166  209.753754  31.469848  34.836539  220.495495    Set4
# 4  26.796607  69.132781  198.527636  29.969077  38.310283  212.483321    Set4
#
#   Ref Shad                                       Img
# 0  C3   A1  D4EECEDB-5CA4-46C9-B28C-63893A5BAF78.png
# 1  C3   A1  E89E9E85-D827-4D54-98B4-0E0F3DD6FDD0.png
# 2  C3   A1  D1227CC3-C06E-4905-A0CF-6A7B8EEFC412.png
# 3  C3   A1  45839274-7758-459E-B7AB-079108195369.png
# 4  C3   A1  4B027C83-D177-47FD-BBAE-4F98F0F0B1F0.png

# %% [markdown]
# ###RGB

# %%
clf23=svm.SVC(kernel='poly')

# %%
RGB_C3_Set4 = table_C3Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_C3_Set2 = table_C3Set2

# %%
RGB_C3_Set3 = table_C3Set3

# %%
RGB_C3_Set1 = table_C3Set1

# %%
RGB_C3_concat0 = pd.concat([RGB_C3_Set2,RGB_C3_Set3,RGB_C3_Set1])

# %%
RGB_C3_concat2 = RGB_C3_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_C3_RGB = np.array(RGB_C3_Set4)

# %%
y_C3_RGB =  table_C3Set4.iloc[:,14:15]

# %%
y_test_C3_RGB = np.array(y_C3_RGB)

# %%
X_train_C3_RGB = np.array(RGB_C3_concat2)

# %%
y_train_C3RGB = RGB_C3_concat0.iloc[:,14:15]

# %%
y_train_C3_RGB = np.array(y_train_C3RGB)

# %%
clf23.fit(X_train_C3_RGB, y_train_C3_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_C3_RGB = clf23.predict(X_test_C3_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_C3_RGB, y_pred_C3_RGB))
# Out:
# Accuracy: 0.33

# %% [markdown]
# ###HSV

# %%
clf24=svm.SVC(kernel='poly')

# %%
HSV_C3_Set4 = table_C3Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_C3_concat2 = RGB_C3_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_C3_HSV = np.array(HSV_C3_Set4)

# %%
y_C3_HSV =  table_C3Set4.iloc[:,14:15]

# %%
y_test_C3_HSV = np.array(y_C3_RGB)

# %%
X_train_C3_HSV = np.array(HSV_C3_concat2)

# %%
y_train_C3HSV = RGB_C3_concat0.iloc[:,14:15]

# %%
y_train_C3_HSV = np.array(y_train_C3HSV)

# %%
clf24.fit(X_train_C3_HSV, y_train_C3_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  27.817710  61.291616  223.691259  34.468874  21.533966  230.929795    Set3
# 1  27.317831  60.943024  223.830290  33.232286  21.096421  230.753835    Set3
# 2  27.505965  60.743203  223.841247  34.479344  21.418229  231.143170    Set3
# 3  27.451181  60.379758  224.122068  34.474150  21.356952  231.587615    Set3
# 4  27.314098  59.597111  225.054785  33.649460  20.631280  232.264670    Set3
#
#   Ref Shad                                       Img
# 0  C4   A1  1BDD234B-AF82-462E-AE9C-B9F424AF15CA.png
# 1  C4   A1  96AC2C34-161B-42E9-ADF7-84C2FB33D103.png
# 2  C4   A1  2B37D6CB-6E6B-4042-96AA-3A2B5FB871AC.png
# 3  C4   A1  130DCFB5-7AE9-49BB-A881-5A08A0ED63F8.png
# 4  C4   A1  B02AE283-B3E2-401F-AEE9-DC33E0828C79.png

# %%
table_C4Set4 = pd.read_excel(Set4, sheet_name='C4_4')
table_C4Set4.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  204.460758  191.779401  152.960474  218.728918  213.325785  193.901794
# 1  203.112653  195.627546  150.388848  217.082217  217.204123  191.091794
# 2  203.696616  196.178800  151.406298  217.191137  217.276844  191.324487
# 3  204.336336  192.744826  152.782566  219.045451  214.668615  193.800828
# 4  202.898628  195.274004  150.578849  216.810080  216.768201  190.808701
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  27.087655  65.681357  204.528123  25.190325  29.276844  218.765685    Set4
# 1  28.584774  67.642967  203.247951  31.467576  31.064524  217.320347    Set4
# 2  28.645808  67.003896  203.834835  31.291535  30.869735  217.372859    Set4
# 3  27.093337  65.761302  204.420826  25.856992  29.693450  219.070530    Set4
# 4  28.501583  67.263209  203.041393  31.174174  31.090252  217.010389    Set4
#
#   Ref Shad                                       Img
# 0  C4   A1  E3CE1857-A5E9-4928-8A37-28BF6EAD7BCD.png
# 1  C4   A1  4820BBED-F65E-4F90-A5EA-283E55866371.png
# 2  C4   A1  2FC399A9-267E-4661-B647-4052082C40FD.png
# 3  C4   A1  93A6C829-4545-4D47-BFB4-721B7DB40A5D.png
# 4  C4   A1  A20513B8-796D-41B5-9512-94978DE63964.png

# %% [markdown]
# ###RGB

# %%
clf25=svm.SVC(kernel='poly')

# %%
RGB_C4_Set4 = table_C4Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_C4_Set2 = table_C4Set2

# %%
RGB_C4_Set3 = table_C4Set3

# %%
RGB_C4_Set1 = table_C4Set1

# %%
RGB_C4_concat0 = pd.concat([RGB_C4_Set2,RGB_C4_Set3,RGB_C4_Set1])

# %%
RGB_C4_concat2 = RGB_C4_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_C4_RGB = np.array(RGB_C4_Set4)

# %%
y_C4_RGB =  table_C4Set4.iloc[:,14:15]

# %%
y_test_C4_RGB = np.array(y_C4_RGB)

# %%
X_train_C4_RGB = np.array(RGB_C4_concat2)

# %%
y_train_C4RGB = RGB_C4_concat0.iloc[:,14:15]

# %%
y_train_C4_RGB = np.array(y_train_C4RGB)

# %%
clf25.fit(X_train_C4_RGB, y_train_C4_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_C4_RGB = clf25.predict(X_test_C4_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_C4_RGB, y_pred_C4_RGB))
# Out:
# Accuracy: 0.40625

# %% [markdown]
# ###HSV

# %%
clf26=svm.SVC(kernel='poly')

# %%
HSV_C4_Set4 = table_C4Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_C4_concat2 = RGB_C4_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_C4_HSV = np.array(HSV_C4_Set4)

# %%
y_C4_HSV =  table_C4Set4.iloc[:,14:15]

# %%
y_test_C4_HSV = np.array(y_C4_RGB)

# %%
X_train_C4_HSV = np.array(HSV_C4_concat2)

# %%
y_train_C4HSV = RGB_C4_concat0.iloc[:,14:15]

# %%
y_train_C4_HSV = np.array(y_train_C4HSV)

# %%
clf26.fit(X_train_C4_HSV, y_train_C4_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_C4_HSV = clf26.predict(X_test_C4_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_C4_HSV, y_pred_C4_HSV))
# Out:
# Accuracy: 0.39125

# %% [markdown]
# #DD

# %% [markdown]
# ##D2

# %%
table_D2Set1 = pd.read_excel(Set1 , sheet_name='D2_1')
table_D2Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  229.583394  213.054785  176.437870  238.772421  224.774369  189.324649
# 1  229.591592  213.256716  176.007223  238.752617  224.901144  188.755864
# 2  225.561724  210.018992  175.575278  234.206152  220.701079  185.125801
# 3  229.641101  213.017693  175.801315  238.640451  224.732246  188.280172
# 4  230.944566  214.487866  178.085464  239.433325  225.713091  190.028650
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  20.675838  59.052674  229.583394  21.531856  52.912588  238.772421    Set1
# 1  20.913075  59.534697  229.591592  21.802451  53.506371  238.752617    Set1
# 2  20.498255  56.504423  225.561724  21.809675  53.523172  234.206152    Set1
# 3  20.738252  59.797500  229.641101  21.780050  53.933609  238.640451    Set1
# 4  20.642561  58.362146  230.944566  21.763493  52.720071  239.433325    Set1
#
#   Ref Shad                                       Img
# 0  D2   A1  BD87D607-5718-45C1-A0DB-D75E63316FD0.png
# 1  D2   A1  FC1BDDC8-C8A7-4C8D-90F6-E6B112FC674F.png
# 2  D2   A1  27DD78A7-D5F3-4BAB-BFE1-8D2D8AB88D29.png
# 3  D2   A1  25A38DEA-0A5E-4502-AE98-BDEB123DF4E5.png
# 4  D2   A1  7396F2FB-8C50-4ED7-AA8C-CDAE1624F900.png

# %%
table_D2Set2 = pd.read_excel(Set2, sheet_name='D2_2')
table_D2Set2.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  223.870140  204.404269  166.035793  230.604091  211.606688  169.541920
# 1  229.075562  211.141141  173.022401  236.169223  218.777047  179.655872
# 2  228.920704  210.064605  172.952277  235.362227  217.619511  179.418797
# 3  229.088629  210.121906  173.959013  235.853421  217.836458  179.304277
# 4  225.360604  206.122474  166.622920  230.679571  211.719828  169.646295
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  19.496794  65.854395  223.870140  20.977518  67.536726  230.604091    Set2
# 1  20.204610  62.463842  229.075562  20.870627  61.099180  236.170522    Set2
# 2  19.545735  62.396559  228.920704  20.456700  60.686389  235.363769    Set2
# 3  19.504261  61.411330  229.088873  20.310446  61.215405  235.853908    Set2
# 4  19.893190  66.454427  225.360604  20.951708  67.486730  230.679571    Set2
#
#   Ref Shad                                       Img
# 0  D2   A1  A6D6A816-ECBC-4ED1-B85A-8F26782873EF.png
# 1  D2   A1  52B93F5E-D972-447C-AEDB-70944733A2A8.png
# 2  D2   A1  8370F6EB-C2ED-4089-AC6F-305D3AC1923F.png
# 3  D2   A1  F1432EC0-7542-4437-B03B-DB680757388E.png
# 4  D2   A1  505DFE06-9B70-46E3-A447-DE5E271DD472.png

# %%
table_D2Set3 = pd.read_excel(Set3, sheet_name='D2_3')
table_D2Set3.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  224.047967  224.033520  207.333983  223.920623  224.360928  203.512621
# 1  231.694343  231.112004  216.498255  232.533236  232.533561  214.600276
# 2  231.474474  230.964532  216.527960  232.049184  231.799286  213.397289
# 3  231.408977  231.515705  216.520899  231.553851  232.501015  213.941076
# 4  231.896843  231.149907  216.603117  231.761789  231.679328  213.081000
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  30.058193  19.687444  224.575197  30.925087  24.168493  224.839867    Set3
# 1  33.427969  17.646457  232.224657  32.275302  20.491437  233.153640    Set3
# 2  33.242837  17.464492  232.048779  31.347861  21.069962  232.469767    Set3
# 3  34.583881  17.636231  232.208912  33.395909  20.834348  232.785326    Set3
# 4  32.781187  17.713335  232.403052  31.429592  21.248194  232.328545    Set3
#
#   Ref Shad                                       Img
# 0  D2   A1  3AADDE41-0882-4926-9B9C-6656A010A4EE.png
# 1  D2   A1  714B814C-2029-4CEC-A3D1-65155C21DB01.png
# 2  D2   A1  FF69DBAD-BCEF-42E0-83C9-26D79EA6F346.png
# 3  D2   A1  D42344C1-B458-48E7-AD35-55850D1E18D6.png
# 4  D2   A1  72143F35-55D4-4615-B8A3-072FC23D36C0.png

# %%
table_D2Set4 = pd.read_excel(Set4, sheet_name='D2_4')
table_D2Set4.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  216.479994  210.505316  189.805373  219.211184  213.217434  189.106404
# 1  219.203555  219.187809  191.554419  223.412223  224.409545  195.440549
# 2  218.680383  218.572762  191.082055  222.532181  223.692882  194.622352
# 3  219.164354  219.247464  192.305251  223.331872  224.525607  195.723074
# 4  219.010957  218.934989  192.454671  222.925574  223.953413  195.302411
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  23.501015  31.425290  216.479994  24.000000  35.024998  219.211184    Set4
# 1  30.992452  32.712361  219.496307  34.011119  33.579661  224.508481    Set4
# 2  30.816168  32.708952  218.942618  34.348835  33.758705  223.726483    Set4
# 3  31.092525  31.780781  219.425371  34.175148  33.268891  224.547115    Set4
# 4  30.990423  31.407921  219.218408  34.047723  33.232368  224.015096    Set4
#
#   Ref Shad                                       Img
# 0  D2   A1  57BFDCD4-3FCB-482B-8F6D-695AB03BA132.png
# 1  D2   A1  A825D098-CB80-4BA0-A769-BC31330B5A5C.png
# 2  D2   A1  320A36C6-A45F-4855-9C69-70F4995F981B.png
# 3  D2   A1  F5718C08-AC9E-4216-9E16-B19FC8625FC9.png
# 4  D2   A1  55184FAB-0359-4CF4-99A1-A38B75A169D0.png

# %% [markdown]
# ###RGB

# %%
clf27=svm.SVC(kernel='poly')

# %%
RGB_D2_Set4 = table_D2Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_D2_Set2 = table_D2Set2

# %%
RGB_D2_Set3 = table_D2Set3

# %%
RGB_D2_Set1 = table_D2Set1

# %%
RGB_D2_concat0 = pd.concat([RGB_D2_Set2,RGB_D2_Set3,RGB_D2_Set1])

# %%
RGB_D2_concat2 = RGB_D2_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_D2_RGB = np.array(RGB_D2_Set4)

# %%
y_D2_RGB =  table_D2Set4.iloc[:,14:15]

# %%
y_test_D2_RGB = np.array(y_D2_RGB)

# %%
X_train_D2_RGB = np.array(RGB_D2_concat2)

# %%
y_train_D2RGB = RGB_D2_concat0.iloc[:,14:15]

# %%
y_train_D2_RGB = np.array(y_train_D2RGB)

# %%
clf27.fit(X_train_D2_RGB, y_train_D2_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_D2_RGB = clf27.predict(X_test_D2_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_D2_RGB, y_pred_D2_RGB))
# Out:
# Accuracy: 0.5025

# %% [markdown]
# ###HSV

# %%
clf28=svm.SVC(kernel='poly')

# %%
HSV_D2_Set4 = table_D2Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_D2_concat2 = RGB_D2_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_D2_HSV = np.array(HSV_D2_Set4)

# %%
y_D2_HSV =  table_D2Set4.iloc[:,14:15]

# %%
y_test_D2_HSV = np.array(y_D2_RGB)

# %%
X_train_D2_HSV = np.array(HSV_D2_concat2)

# %%
y_train_D2HSV = RGB_D2_concat0.iloc[:,14:15]

# %%
y_train_D2_HSV = np.array(y_train_D2HSV)

# %%
clf28.fit(X_train_D2_HSV, y_train_D2_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_D2_HSV = clf28.predict(X_test_D2_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_D2_HSV, y_pred_D2_HSV))
# Out:
# Accuracy: 0.15875

# %% [markdown]
# ##D3

# %%
table_D3Set1 = pd.read_excel(Set1 , sheet_name='D3_1')
table_D3Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  228.510511  211.399805  175.184319  237.226199  228.016476  200.901469
# 1  228.129129  211.503612  175.244136  236.603766  227.822904  200.566918
# 2  228.871520  211.994724  175.859914  237.001867  227.893028  200.972648
# 3  228.052187  210.838731  175.080513  236.595244  227.451100  200.969889
# 4  228.468063  211.528610  175.837919  236.582664  227.768688  201.413522
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  20.272380  59.524146  228.510511  22.376836  39.147553  237.226199    Set1
# 1  20.523496  59.110705  228.129129  22.657739  38.919893  236.603766    Set1
# 2  20.373590  59.093418  228.871520  22.452398  38.869410  237.001867    Set1
# 3  20.101534  59.246652  228.052187  22.265238  38.493791  236.595244    Set1
# 4  20.250872  58.743933  228.468063  22.447934  37.983524  236.582664    Set1
#
#   Ref Shad                                       Img
# 0  D3   A1  57601EF7-37D5-4783-A278-238D30F60912.png
# 1  D3   A1  5412037F-4AF3-43A2-A4ED-CADFEC0751E7.png
# 2  D3   A1  456A44EC-FCBD-4487-B70C-F0E01333D15C.png
# 3  D3   A1  834A3691-A011-4D07-8652-E2A2C8F1E3F7.png
# 4  D3   A1  714E83ED-391B-480A-85E8-DC4AB8864683.png

# %%
table_D3Set2 = pd.read_excel(Set2, sheet_name='D3_2')
table_D3Set2.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  232.070936  209.067283  157.989692  239.136353  222.454022  182.198766
# 1  231.924276  208.816249  157.763737  238.650597  222.199740  181.596137
# 2  231.976301  208.732814  158.072884  238.462787  221.327652  181.318399
# 3  233.108108  209.612856  159.696940  239.666099  222.948381  182.487298
# 4  232.364013  208.626410  158.721776  238.341937  221.653194  181.328220
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0
drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_D3_Set2 = table_D3Set2

# %%
RGB_D3_Set3 = table_D3Set3

# %%
RGB_D3_Set1 = table_D3Set1

# %%
RGB_D3_concat0 = pd.concat([RGB_D3_Set2,RGB_D3_Set3,RGB_D3_Set1])

# %%
RGB_D3_concat2 = RGB_D3_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_D3_RGB = np.array(RGB_D3_Set4)

# %%
y_D3_RGB =  table_D3Set4.iloc[:,14:15]

# %%
y_test_D3_RGB = np.array(y_D3_RGB)

# %%
X_train_D3_RGB = np.array(RGB_D3_concat2)

# %%
y_train_D3RGB = RGB_D3_concat0.iloc[:,14:15]

# %%
y_train_D3_RGB = np.array(y_train_D3RGB)

# %%
clf29.fit(X_train_D3_RGB, y_train_D3_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_D3_RGB = clf29.predict(X_test_D3_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_D3_RGB, y_pred_D3_RGB))
# Out:
# Accuracy: 0.64

# %% [markdown]
# ###HSV

# %%
clf30=svm.SVC(kernel='poly')

# %%
HSV_D3_Set4 = table_D3Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_D3_concat2 = RGB_D3_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_D3_HSV = np.array(HSV_D3_Set4)

# %%
y_D3_HSV =  table_D3Set4.iloc[:,14:15]

# %%
y_test_D3_HSV = np.array(y_D3_RGB)

# %%
X_train_D3_HSV = np.array(HSV_D3_concat2)

# %%
y_train_D3HSV = RGB_D3_concat0.iloc[:,14:15]

# %%
y_train_D3_HSV = np.array(y_train_D3HSV)

# %%
clf30.fit(X_train_D3_HSV, y_train_D3_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_D3_HSV = clf30.predict(X_test_D3_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_D3_HSV, y_pred_D3_HSV))
# Out:
# Accuracy: 0.39625

# %% [markdown]
# ##D4

# %%
table_D4Set1 = pd.read_excel(Set1 , sheet_name='D4_1')
table_D4Set1.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0  227.056245  211.571463  168.959419  237.027108  227.815437  201.336336
# 1  233.195520  218.202419  174.711468  242.102995  233.097557  206.069962
# 2  233.881828  218.251035  175.251684  242.403701  232.743771  206.657495
# 3  234.888483  217.971512  172.875497  242.177908  231.738171  202.928740
# 4  235.071910  217.812921  173.771285  241.939778  231.022644  203.341531
#
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  22.046668  65.277169  227.056245  22.217271  38.458648  237.027108    Set1
# 1  22.280253  63.967535  233.195520  22.487866  37.996754  242.102995    Set1
# 2  22.110624  63.980683  233.881828  22.006574  37.638341  242.403701    Set1
# 3  22.057706  67.348186  234.888483  21.964938  41.334713  242.177908    Set1
# 4  21.915023  66.522604  235.071910  21.506452  40.718611  241.939778    Set1
#
#   Ref Shad                                       Img
# 0  D4   A1  D47BC759-4BF1-40D8-9D68-52766A1B3358.png
# 1  D4   A1  63D0E875-9DA6-4483-BB03-E54DC1E8BC87.png
# 2  D4   A1  779692A7-DE00-4434-843B-AEB78B8B0AF8.png
# 3  D4   A1  18456DEB-40B5-49F7-B753-562994BE1B43.png
# 4  D4   A1  72376331-D805-4BAC-AE50-7A04A6729880.png

# %%
table_D4Set2 = pd.read_excel(Set2, sheet_name='D4_2')
table_D4Set2.head()
# Out:
#         R-ref       G-ref       B-ref      R-Shad      G-Shad      B-Shad  \
# 0
#        H-ref      S-ref       V-ref     H-Shad     S-Shad      V-Shad Setting  \
# 0  27.807970  61.131889  222.041636  26.301355  28.931418  230.716906    Set4
# 1  28.318724  69.625842  213.700024  28.999351  35.383410  220.924681    Set4
# 2  30.037659  61.510592  219.985066  31.519033  30.358007  228.646214    Set4
# 3  28.015908  69.228634  213.412142  29.040825  34.900170  220.942537    Set4
# 4  28.151286  69.178476  213.226524  29.391851  34.873630  220.587777    Set4
#
#   Ref Shad                                       Img
# 0  D4   A1  C5F56A54-2D34-4B30-986F-F5C15CDF3EC4.png
# 1  D4   A1  E1E6AA11-2B77-40D9-A177-059926CC439D.png
# 2  D4   A1  74A96958-C7AA-4963-AA46-D100224ADF7D.png
# 3  D4   A1  CA71D6C8-B603-4820-8CBF-DE4735A760F9.png
# 4  D4   A1  DC8E94B0-D1C9-4C1B-910E-4CDC0E62706B.png

# %% [markdown]
# ###RGB

# %%
clf31=svm.SVC(kernel='poly')

# %%
RGB_D4_Set4 = table_D4Set4.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
RGB_D4_Set2 = table_D4Set2

# %%
RGB_D4_Set3 = table_D4Set3

# %%
RGB_D4_Set1 = table_D4Set1

# %%
RGB_D4_concat0 = pd.concat([RGB_D4_Set2,RGB_D4_Set3,RGB_D4_Set1])

# %%
RGB_D4_concat2 = RGB_D4_concat0.drop(['H-ref','S-ref','V-ref','H-Shad','S-Shad','V-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_D4_RGB = np.array(RGB_D4_Set4)

# %%
y_D4_RGB =  table_D4Set4.iloc[:,14:15]

# %%
y_test_D4_RGB = np.array(y_D4_RGB)

# %%
X_train_D4_RGB = np.array(RGB_D4_concat2)

# %%
y_train_D4RGB = RGB_D4_concat0.iloc[:,14:15]

# %%
y_train_D4_RGB = np.array(y_train_D4RGB)

# %%
clf31.fit(X_train_D4_RGB, y_train_D4_RGB)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_D4_RGB = clf31.predict(X_test_D4_RGB)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_D4_RGB, y_pred_D4_RGB))
# Out:
# Accuracy: 0.7425

# %% [markdown]
# ###HSV

# %%
clf32=svm.SVC(kernel='poly')

# %%
HSV_D4_Set4 = table_D4Set4.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
HSV_D4_concat2 = RGB_D4_concat0.drop(['R-ref','G-ref','B-ref','R-Shad','G-Shad','B-Shad','Setting','Ref','Shad','Img'], axis=1)

# %%
X_test_D4_HSV = np.array(HSV_D4_Set4)

# %%
y_D4_HSV =  table_D4Set4.iloc[:,14:15]

# %%
y_test_D4_HSV = np.array(y_D4_RGB)

# %%
X_train_D4_HSV = np.array(HSV_D4_concat2)

# %%
y_train_D4HSV = RGB_D4_concat0.iloc[:,14:15]

# %%
y_train_D4_HSV = np.array(y_train_D4HSV)

# %%
clf32.fit(X_train_D4_HSV, y_train_D4_HSV)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='poly')

# %%
y_pred_D4_HSV = clf32.predict(X_test_D4_HSV)

# %%
print("Accuracy:", metrics.accuracy_score(y_test_D4_HSV, y_pred_D4_HSV))
# Out:
# Accuracy: 0.55

# %% [markdown]
# #Accuracy

# %% [markdown]
# ##RGB

# %%
print("A1 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A1_RGB, y_pred_A1_RGB))
print("A2 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A2_RGB, y_pred_A2_RGB))
print("A3 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A3_RGB, y_pred_A3_RGB))
print("A3.5 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A3_5_RGB, y_pred_A3_5_RGB))
print("A4 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A4_RGB, y_pred_A4_RGB))
print("B1 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_B1_RGB, y_pred_B1_RGB))
print("B2 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_B2_RGB, y_pred_B2_RGB))
print("B3 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_B3_RGB, y_pred_B3_RGB))
print("B4 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_B4_RGB, y_pred_B4_RGB))
print("C1 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_C1_RGB, y_pred_C1_RGB))
print("C2 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_C2_RGB, y_pred_C2_RGB))
print("C3 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_C3_RGB, y_pred_C3_RGB))
print("C4 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_C4_RGB, y_pred_C4_RGB))
print("D2 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_D2_RGB, y_pred_D2_RGB))
print("D3 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_D3_RGB, y_pred_D3_RGB))
print("D4 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_D4_RGB, y_pred_D4_RGB))
# Out:
# A1 มี Accuracy เท่ากับ: 0.7675
# A2 มี Accuracy เท่ากับ: 0.93
# A3 มี Accuracy เท่ากับ: 0.8925
# A3.5 มี Accuracy เท่ากับ: 0.355
# A4 มี Accuracy เท่ากับ: 0.7775
# B1 มี Accuracy เท่ากับ: 0.57375
# B2 มี Accuracy เท่ากับ: 0.55375
# B3 มี Accuracy เท่ากับ: 0.76625
# B4 มี Accuracy เท่ากับ: 0.53875
# C1 มี Accuracy เท่ากับ: 0.09625
# C2 มี Accuracy เท่ากับ: 0.8225
# C3 มี Accuracy เท่ากับ: 0.33
# C4 มี Accuracy เท่ากับ: 0.40625
# D2 มี Accuracy เท่ากับ: 0.5025
# D3 มี Accuracy เท่ากับ: 0.64
# D4 มี Accuracy เท่ากับ: 0.7425

# %%
RGB_AC_A1 = metrics.accuracy_score(y_test_A1_RGB, y_pred_A1_RGB)
RGB_AC_A2 = metrics.accuracy_score(y_test_A2_RGB, y_pred_A2_RGB)
RGB_AC_A3 = metrics.accuracy_score(y_test_A3_RGB, y_pred_A3_RGB)
RGB_AC_A35 = metrics.accuracy_score(y_test_A3_5_RGB, y_pred_A3_5_RGB)
RGB_AC_A4 = metrics.accuracy_score(y_test_A4_RGB, y_pred_A4_RGB)
RGB_AC_B1 = metrics.accuracy_score(y_test_B1_RGB, y_pred_B1_RGB)
RGB_AC_B2 = metrics.accuracy_score(y_test_B2_RGB, y_pred_B2_RGB)
RGB_AC_B3 = metrics.accuracy_score(y_test_B3_RGB, y_pred_B3_RGB)
RGB_AC_B4 = metrics.accuracy_score(y_test_B4_RGB, y_pred_B4_RGB)
RGB_AC_C1 = metrics.accuracy_score(y_test_C1_RGB, y_pred_C1_RGB)
RGB_AC_C2 = metrics.accuracy_score(y_test_C2_RGB, y_pred_C2_RGB)
RGB_AC_C3 = metrics.accuracy_score(y_test_C3_RGB, y_pred_C3_RGB)
RGB_AC_C4 = metrics.accuracy_score(y_test_C4_RGB, y_pred_C4_RGB)
RGB_AC_D2 = metrics.accuracy_score(y_test_D2_RGB, y_pred_D2_RGB)
RGB_AC_D3 = metrics.accuracy_score(y_test_D3_RGB, y_pred_D3_RGB)
RGB_AC_D4 = metrics.accuracy_score(y_test_D4_RGB, y_pred_D4_RGB)

# %%
RGB_AC =  (RGB_AC_A1,RGB_AC_A2,RGB_AC_A3,RGB_AC_A35,
           RGB_AC_A4,RGB_AC_B1,RGB_AC_B2,RGB_AC_B3,
           RGB_AC_B4,RGB_AC_C1,RGB_AC_C2,RGB_AC_C3,
           RGB_AC_C4,RGB_AC_D2,RGB_AC_D3,RGB_AC_D4)

# %%
RGB_AC
# Out:
# (0.7675,
#  0.93,
#  0.8925,
#  0.355,
#  0.7775,
#  0.57375,
#  0.55375,
#  0.76625,
#  0.53875,
#  0.09625,
#  0.8225,
#  0.33,
#  0.40625,
#  0.5025,
#  0.64,
#  0.7425)

# %%
list_RGB_AC = list()
list_RGB_AC.append(RGB_AC)

# %%
Cols = ['Set4_rgb'] 
S1_1 = pd.DataFrame(RGB_AC,columns= Cols)
S1_1
# Out:
#     Set4_rgb
# 0    0.76750
# 1    0.93000
# 2    0.89250
# 3    0.35500
# 4    0.77750
# 5    0.57375
# 6    0.55375
# 7    0.76625
# 8    0.53875
# 9    0.09625
# 10   0.82250
# 11   0.33000
# 12   0.40625
# 13   0.50250
# 14   0.64000
# 15   0.74250

# %% [markdown]
# ##HSV

# %%
print("A1 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A1_HSV, y_pred_A1_HSV))
print("A2 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A2_HSV, y_pred_A2_HSV))
print("A3 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A3_HSV, y_pred_A3_HSV))
print("A3.5 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A3_5_HSV, y_pred_A3_5_HSV))
print("A4 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_A4_HSV, y_pred_A4_HSV))
print("B1 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_B1_HSV, y_pred_B1_HSV))
print("B2 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_B2_HSV, y_pred_B2_HSV))
print("B3 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_B3_HSV, y_pred_B3_HSV))
print("B4 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_B4_HSV, y_pred_B4_HSV))
print("C1 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_C1_HSV, y_pred_C1_HSV))
print("C2 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_C2_HSV, y_pred_C2_HSV))
print("C3 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_C3_HSV, y_pred_C3_HSV))
print("C4 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_C4_HSV, y_pred_C4_HSV))
print("D2 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_D2_HSV, y_pred_D2_HSV))
print("D3 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_D3_HSV, y_pred_D3_HSV))
print("D4 มี Accuracy เท่ากับ:", metrics.accuracy_score(y_test_D4_HSV, y_pred_D4_HSV))
# Out:
# A1 มี Accuracy เท่ากับ: 0.5325
# A2 มี Accuracy เท่ากับ: 0.59375
# A3 มี Accuracy เท่ากับ: 0.54
# A3.5 มี Accuracy เท่ากับ: 0.23875
# A4 มี Accuracy เท่ากับ: 0.47
# B1 มี Accuracy เท่ากับ: 0.37625
# B2 มี Accuracy เท่ากับ: 0.46
# B3 มี Accuracy เท่ากับ: 0.41625
# B4 มี Accuracy เท่ากับ: 0.2875
# C1 มี Accuracy เท่ากับ: 0.2675
# C2 มี Accuracy เท่ากับ: 0.3075
# C3 มี Accuracy เท่ากับ: 0.205
# C4 มี Accuracy เท่ากับ: 0.39125
# D2 มี Accuracy เท่ากับ: 0.15875
# D3 มี Accuracy เท่ากับ: 0.39625
# D4 มี Accuracy เท่ากับ: 0.55

# %%
HSV_AC_A1 = metrics.accuracy_score(y_test_A1_HSV, y_pred_A1_HSV)
HSV_AC_A2 = metrics.accuracy_score(y_test_A2_HSV, y_pred_A2_HSV)
HSV_AC_A3 = metrics.accuracy_score(y_test_A3_HSV, y_pred_A3_HSV)
HSV_AC_A35 = metrics.accuracy_score(y_test_A3_5_HSV, y_pred_A3_5_HSV)
HSV_AC_A4 = metrics.accuracy_score(y_test_A4_HSV, y_pred_A4_HSV)
HSV_AC_B1 = metrics.accuracy_score(y_test_B1_HSV, y_pred_B1_HSV)
HSV_AC_B2 = metrics.accuracy_score(y_test_B2_HSV, y_pred_B2_HSV)
HSV_AC_B3 = metrics.accuracy_score(y_test_B3_HSV, y_pred_B3_HSV)
HSV_AC_B4 = metrics.accuracy_score(y_test_B4_HSV, y_pred_B4_HSV)
HSV_AC_C1 = metrics.accuracy_score(y_test_C1_HSV, y_pred_C1_HSV)
HSV_AC_C2 = metrics.accuracy_score(y_test_C2_HSV, y_pred_C2_HSV)
HSV_AC_C3 = metrics.accuracy_score(y_test_C3_HSV, y_pred_C3_HSV)
HSV_AC_C4 = metrics.accuracy_score(y_test_C4_HSV, y_pred_C4_HSV)
HSV_AC_D2 = metrics.accuracy_score(y_test_D2_HSV, y_pred_D2_HSV)
HSV_AC_D3 = metrics.accuracy_score(y_test_D3_HSV, y_pred_D3_HSV)
HSV_AC_D4 = metrics.accuracy_score(y_test_D4_HSV, y_pred_D4_HSV)

# %%
HSV_AC =  (HSV_AC_A1,HSV_AC_A2,HSV_AC_A3,HSV_AC_A35,
           HSV_AC_A4,HSV_AC_B1,HSV_AC_B2,HSV_AC_B3,
           HSV_AC_B4,HSV_AC_C1,HSV_AC_C2,HSV_AC_C3,
           HSV_AC_C4,HSV_AC_D2,HSV_AC_D3,HSV_AC_D4)

# %%
list_HSV_AC = list()
list_HSV_AC.append(RGB_AC)

# %%
Cols = ['Set4_hsv'] 
S1_2 = pd.DataFrame(HSV_AC,columns= Cols)
S1_2
# Out:
#     Set4_hsv
# 0    0.53250
# 1    0.59375
# 2    0.54000
# 3    0.23875
# 4    0.47000
# 5    0.37625
# 6    0.46000
# 7    0.41625
# 8    0.28750
# 9    0.26750
# 10   0.30750
# 11   0.20500
# 12   0.39125
# 13   0.15875
# 14   0.39625
# 15   0.55000

# %%
name =  ('A1','A2','A3','A3.5','A4','B1','B2','B3','B4','C1','C2','C3','C4','D2','D3','D4')

# %%
Cols = ['shade'] 
S1_3 = pd.DataFrame(name,columns= Cols)
S1_3
# Out:
#    shade
# 0     A1
# 1     A2
# 2     A3
# 3   A3.5
# 4     A4
# 5     B1
# 6     B2
# 7     B3
# 8     B4
# 9     C1
# 10    C2
# 11    C3
# 12    C4
# 13    D2
# 14    D3
# 15    D4

# %%
Data_RF = pd.concat([S1_3,S1_1,S1_2], axis=1)
Data_RF
# Out:
#    shade  Set4_rgb  Set4_hsv
# 0     A1   0.76750   0.53250
# 1     A2   0.93000   0.59375
# 2     A3   0.89250   0.54000
# 3   A3.5   0.35500   0.23875
# 4     A4   0.77750   0.47000
# 5     B1   0.57375   0.37625
# 6     B2   0.55375   0.46000
# 7     B3   0.76625   0.41625
# 8     B4   0.53875   0.28750
# 9     C1   0.09625   0.26750
# 10    C2   0.82250   0.30750
# 11    C3   0.33000   0.20500
# 12    C4   0.40625   0.39125
# 13    D2   0.50250   0.15875
# 14    D3   0.64000   0.39625
# 15    D4   0.74250   0.55000

# %%
Data_RF.to_csv('Data_AcSVMset4.csv', index=False)
